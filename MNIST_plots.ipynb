# %%
import torch
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
without_ga = [0.8777698278427124,
 0.9082208871841431,
 0.9238902926445007,
 0.9380504488945007,
 0.9456232190132141]

q_10 = [0.8790483474731445,
 0.9074662923812866,
 0.9245028495788574,
 0.9377219080924988,
 0.9454900622367859]

q_5 = [0.8731711506843567,
 0.9066140055656433,
 0.9200372695922852,
 0.9397106170654297,
 0.9478604197502136]

q_2=[0.8671075701713562,
 0.9048296213150024,
 0.9226473569869995,
 0.9372336268424988,
 0.9462180137634277]

q_1=[0.8595792055130005,
 0.9023259878158569,
 0.9206854104995728,
 0.9361950159072876,
 0.9475231170654297]

df = pd.DataFrame({'Without Gaussian Approximation': without_ga, 
                   'q=10': q_10, 
                   'q=5': q_5, 
                   'q=2': q_2, 
                   'q=1': q_1
                   }
                  )

df.index = pd.RangeIndex(start=1, stop=len(df) + 1, step=1)

# Initialize the Seaborn style
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
ax = sns.lineplot(data=df, markers=True, dashes=False)

ax.set_xlabel('Round')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy over Rounds (MNIST)')

# Show the plot
plt.show()
