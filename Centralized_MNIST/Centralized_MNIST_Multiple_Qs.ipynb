# %% [markdown]
# # Test Results

# %%
import os
os.chdir('..')
os.getcwd()
# Out:
# '/Users/rohaan/Desktop/storage/RIT/federated_learning_lab'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import json
import numpy as np
import random
import matplotlib.pyplot as plt

# Set device (GPU if available)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
def set_seed(seed):
    torch.manual_seed(seed)           # For CPU
    torch.cuda.manual_seed(seed)      # For CUDA (if using GPU)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU
    np.random.seed(seed)              # For NumPy
    random.seed(seed)                 # For Python's built-in random
    torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
    torch.backends.cudnn.benchmark = False     # Turn off optimization for reproducibility

# %%
transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Resize to 32x32 as required by LeNet-5
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
print(f"Datasets:\n\t-> TRAIN: {'available' if train_dataset else 'N/A'}\n\t-> TEST: {'available' if train_dataset else 'N/A'}")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100.0%
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Datasets:
# 	-> TRAIN: available
# 	-> TEST: available

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=1000, shuffle=False)

print(f"Datasets:\n\t-> TRAIN: {len(train_loader.dataset)} samples\n\t-> TEST: {len(test_loader.dataset)} samples")
# Out:
# Datasets:
# 	-> TRAIN: 60000 samples
# 	-> TEST: 10000 samples

# %%
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        # kernel_size aka filter size
        # out_channels aka number of filters
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=120, kernel_size=5, stride=1)
        self.fc1 = nn.Linear(in_features=120, out_features=84)
        self.fc2 = nn.Linear(in_features=84, out_features=10)

    def forward(self, x):
        # layer 1
        x = self.conv1(x)
        x = torch.tanh(x) 
        # layer 2
        x = nn.functional.avg_pool2d(input=x, kernel_size=2, stride=2)
        x = torch.tanh(x) 
        # layer 3
        x = self.conv2(x)
        x = torch.tanh(x) 
        # layer 4
        x = nn.functional.avg_pool2d(input=x, kernel_size=2, stride=2)
        x = torch.tanh(x) 
        # layer 5
        x = self.conv3(x)
        x = torch.tanh(x) 
        # layer 6
        x = torch.flatten(x, start_dim=1)
        x = self.fc1(x)
        x = torch.tanh(x) 
        # output layer
        x = self.fc2(x)
        # x = nn.functional.softmax(x, dim=1)  # remove softmax if using crossEntropy since it applies the softmax function too
    
        return x

# %%
def train(model, device, train_loader, optimizer, criterion, epoch, new_updates=None, track_weights=False):
    model.train()
    train_loss = 0
    
    # Apply new updates to model weights if provided
    if new_updates is not None:
        with torch.no_grad():
            current_weights = {name: weights for name, weights in model.state_dict().items()}
            updated_weights = {name: current_weights[name] + new_updates[name].clone().detach()
                               for name in current_weights}
            model.load_state_dict(updated_weights)
    
    # Capture initial weights after applying new updates
    w_t = {name: weights.clone().detach().cpu() for name, weights in model.state_dict().items()}
    
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        
        if batch_idx % 100 == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)}]\tLoss: {loss.item():.6f}')

    avg_train_loss = train_loss / len(train_loader.dataset)
    
    
    # Capture updated weights after training
    w_t_plus_1 = {name: weights.clone().detach().cpu() for name, weights in model.state_dict().items()}
    
    # Calculate weight updates
    weight_updates = {
        name: (w_t_plus_1[name] - w_t[name]) 
        for name in w_t
    }
    
    if track_weights:    
        # Save weight updates if tracking is on
        with open(f'save/LeNet5/updates_epoch_{epoch}.json', 'w') as json_file:
            json.dump(weight_updates, json_file)
            
    return weight_updates, avg_train_loss

# %%
def initialize_model(seed=42):
    set_seed(seed)
    model = LeNet5()
    return model

# %%
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()  # Sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # Get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    avg_test_loss = test_loss / len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print(f'\nTest set: Average loss: {avg_test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} ({accuracy:.0f}%)\n')

    return avg_test_loss, accuracy

# %%
def flatten_vector(state_dict):
    flat_vector = []
    shapes = {}

    for name, tensor in state_dict.items():
        flattened_tensor = tensor.view(-1)  # Flatten the tensor into a 1D vector
        flat_vector.append(flattened_tensor)
        shapes[name] = tensor.shape  # Store the original shape

    # Concatenate all flattened tensors into a single 1D vector
    flat_vector = torch.cat(flat_vector)

    return flat_vector, shapes

# %%
def vector_to_state_dict(flat_vector, shapes):
    reconstructed_state_dict = {}
    current_index = 0

    for name, shape in shapes.items():
        # Calculate the number of elements in the tensor
        num_elements = torch.prod(torch.tensor(shape))
        # Extract the corresponding portion from the flat vector
        flattened_tensor = flat_vector[current_index:current_index + num_elements]
        # Reshape the 1D tensor back to its original shape
        tensor = flattened_tensor.view(shape)
        # Add the tensor back to the state_dict
        reconstructed_state_dict[name] = tensor
        # Update the current index
        current_index += num_elements

    return reconstructed_state_dict

# %%
class GA:
    def __init__(self, 
                 seed: int, 
                 d: int, 
                 q: int, 
                 device: torch.device = torch.device("cpu")) -> None:
        self.seed = seed
        self.d = d
        self.q = q
        self.device = device
        torch.manual_seed(self.seed)
        
        print(f'GA initialized with seed={seed}, d={d}, q={q}, device={device}')
        
    def G(self) -> torch.Tensor:
        return torch.rand(self.d, self.q).to(self.device)
    
    def w(self, delta: torch.Tensor) -> torch.Tensor:
        GT = self.G().t()  # Transpose the tensor
        return torch.matmul(GT, delta) / self.q
    
    def delta(self, w: torch.Tensor) -> torch.Tensor:
        return torch.matmul(self.G(), w)

# %%
def normalize(tensor: torch.Tensor, min_val: float = 0.0, max_val: float = 1.0) -> torch.Tensor:
    tensor_min = tensor.min()
    tensor_max = tensor.max()
    
    # Scale tensor to range [0, 1]
    normalized_tensor = (tensor - tensor_min) / (tensor_max - tensor_min)
    
    # Scale to desired range [min_val, max_val]
    normalized_tensor = normalized_tensor * (max_val - min_val) + min_val
    
    return normalized_tensor

# %%
def generate_qs(min=1, max=2e4):
    qs=[]
    q = min
    while (abs(q) <= max):
        qs.append(q)
        q *= 2
    return qs
        
generate_qs()
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384]

# %%
num_epochs = 5
lr = 0.01

results = {}
approximation_errors = {}
for q in generate_qs(max=61706*2):
    print('q=',q)
    results[q] = {}
    approximation_errors[q] = {}
    model = initialize_model(seed=1829).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    train_losses = []
    test_losses = []
    accuracies = []

    for epoch in range(1, 1 + num_epochs):
        if epoch == 1:
            new_updates = None
        
        current_weights = {name: weights for name, weights in model.state_dict().items()}
        
        weight_updates, avg_train_loss = train(model=model, 
                                            device=device, 
                                            train_loader=train_loader, 
                                            optimizer=optimizer, 
                                            criterion=criterion, 
                                            epoch=epoch, 
                                            new_updates=new_updates,
                                            track_weights=False)
        real_delta, shapes = flatten_vector(weight_updates)
        seed = random.randint(0, 100)
        ga = GA(seed=seed,
                d=len(real_delta),
                q=q)
        w = ga.w(real_delta)
        approximated_delta = ga.delta(w)
        normalized_delta = normalize(tensor=approximated_delta,
                                    min_val=real_delta.min(),
                                    max_val=real_delta.max())
        l2_norm_error = torch.norm(real_delta - normalized_delta, p=2)
        approximation_errors[q][epoch] = l2_norm_error
        new_updates = vector_to_state_dict(flat_vector=normalized_delta,
                                        shapes=shapes)
        
        
        updated_weights = {name: current_weights[name] + new_updates[name].clone().detach()
                               for name in current_weights}
        
        model.load_state_dict(updated_weights)
        
        avg_test_loss, accuracy = test(model, device, test_loader)
        
        train_losses.append(avg_train_loss)
        test_losses.append(avg_test_loss)
        accuracies.append(accuracy)
        
        results[q]['train_losses'] = train_losses
        results[q]['test_losses'] = test_losses
        results[q]['accuracies'] = accuracies
# Out:
# q= 1
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=1, device=cpu
#
# Test set: Average loss: 0.0105, Accuracy: 1347/10000 (13%)
#
# Train Epoch: 2 [0/60000]	Loss: 22.023558
# Train Epoch: 2 [6400/60000]	Loss: 2.725859
# Train Epoch: 2 [12800/60000]	Loss: 1.595773
# Train Epoch: 2 [19200/60000]	Loss: 1.949723
# Train Epoch: 2 [25600/60000]	Loss: 1.114307
# Train Epoch: 2 [32000/60000]	Loss: 0.686785
# Train Epoch: 2 [38400/60000]	Loss: 0.635350
# Train Epoch: 2 [44800/60000]	Loss: 1.220805
# Train Epoch: 2 [51200/60000]	Loss: 0.740558
# Train Epoch: 2 [57600/60000]	Loss: 0.762842
# GA initialized with seed=90, d=61706, q=1, device=cpu
#
# Test set: Average loss: 0.0184, Accuracy: 1603/10000 (16%)
#
# Train Epoch: 3 [0/60000]	Loss: 53.746769
# Train Epoch: 3 [6400/60000]	Loss: 13.342128
# Train Epoch: 3 [12800/60000]	Loss: 5.938220
# Train Epoch: 3 [19200/60000]	Loss: 3.421302
# Train Epoch: 3 [25600/60000]	Loss: 3.770653
# Train Epoch: 3 [32000/60000]	Loss: 4.852882
# Train Epoch: 3 [38400/60000]	Loss: 3.155817
# Train Epoch: 3 [44800/60000]	Loss: 3.061944
# Train Epoch: 3 [51200/60000]	Loss: 1.423218
# Train Epoch: 3 [57600/60000]	Loss: 2.249498
# GA initialized with seed=20, d=61706, q=1, device=cpu
#
# Test set: Average loss: 0.0384, Accuracy: 1353/10000 (14%)
#
# Train Epoch: 4 [0/60000]	Loss: 97.834396
# Train Epoch: 4 [6400/60000]	Loss: 36.971905
# Train Epoch: 4 [12800/60000]	Loss: 26.900627
#
# Test set: Average loss: 0.0035, Accuracy: 4584/10000 (46%)
#
# Train Epoch: 5 [0/60000]	Loss: 10.614980
# Train Epoch: 5 [6400/60000]	Loss: 1.642541
# Train Epoch: 5 [12800/60000]	Loss: 2.239280
# Train Epoch: 5 [19200/60000]	Loss: 1.950122
# Train Epoch: 5 [25600/60000]	Loss: 1.435920
# Train Epoch: 5 [32000/60000]	Loss: 0.682809
# Train Epoch: 5 [38400/60000]	Loss: 0.523855
# Train Epoch: 5 [44800/60000]	Loss: 0.646493
# Train Epoch: 5 [51200/60000]	Loss: 0.494402
# Train Epoch: 5 [57600/60000]	Loss: 0.630716
# GA initialized with seed=32, d=61706, q=128, device=cpu
#
# Test set: Average loss: 0.0032, Accuracy: 4293/10000 (43%)
#
# q= 256
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=256, device=cpu
#
# Test set: Average loss: 0.0023, Accuracy: 5117/10000 (51%)
#
# Train Epoch: 2 [0/60000]	Loss: 6.256984
# Train Epoch: 2 [6400/60000]	Loss: 1.094392
# Train Epoch: 2 [12800/60000]	Loss: 0.572179
# Train Epoch: 2 [19200/60000]	Loss: 0.783949
# Train Epoch: 2 [25600/60000]	Loss: 0.494952
# Train Epoch: 2 [32000/60000]	Loss: 0.679349
# Train Epoch: 2 [38400/60000]	Loss: 0.417135
# Train Epoch: 2 [44800/60000]	Loss: 0.408768
# Train Epoch: 2 [51200/60000]	Loss: 0.582628
# Train Epoch: 2 [57600/60000]	Loss: 0.408938
# GA initialized with seed=90, d=61706, q=256, device=cpu
#
# Test set: Average loss: 0.0076, Accuracy: 3277/10000 (33%)
#
# Train Epoch: 3 [0/60000]	Loss: 19.324497
# Train Epoch: 3 [6400/60000]	Loss: 1.432686
# Train Epoch: 3 [12800/60000]	Loss: 1.275996
# Train Epoch: 3 [19200/60000]	Loss: 1.252271
# Train Epoch: 3 [25600/60000]	Loss: 1.416492
# Train Epoch: 3 [32000/60000]	Loss: 0.714758
# Train Epoch: 3 [38400/60000]	Loss: 1.002096
# Train Epoch: 3 [44800/60000]	Loss: 0.932803
# Train Epoch: 3 [51200/60000]	Loss: 0.637990
# Train Epoch: 3 [57600/60000]	Loss: 0.810819
# GA initialized with seed=20, d=61706, q=256, device=cpu
#
# Test set: Average loss: 0.0150, Accuracy: 2531/10000 (25%)
#
# Train Epoch: 4 [0/60000]	Loss: 16.970713
# Train Epoch: 4 [6400/60000]	Loss: 2.244620
# Train Epoch: 4 [12800/60000]	Loss: 1.767724
# Train Epoch: 4 [19200/60000]	Loss: 1.570331
# Train Epoch: 4 [25600/60000]	Loss: 1.169185
# Train Epoch: 4 [32000/60000]	Loss: 1.245219
# Train Epoch: 4 [38400/60000]	Loss: 0.866664
# Train Epoch: 4 [44800/60000]	Loss: 1.113515
# Train Epoch: 4 [51200/60000]	Loss: 0.866416
# Train Epoch: 4 [57600/60000]	Loss: 0.943455
# GA initialized with seed=22, d=61706, q=256, device=cpu
#
# Test set: Average loss: 0.0242, Accuracy: 1702/10000 (17%)
#
# Train Epoch: 5 [0/60000]	Loss: 29.056936
# Train Epoch: 5 [6400/60000]	Loss: 2.620511
# Train Epoch: 5 [12800/60000]	Loss: 2.033736
# Train Epoch: 5 [19200/60000]	Loss: 2.133552
# Train Epoch: 5 [25600/60000]	Loss: 2.061411
# Train Epoch: 5 [32000/60000]	Loss: 2.098801
# Train Epoch: 5 [38400/60000]	Loss: 1.807856
# Train Epoch: 5 [44800/60000]	Loss: 1.570230
# Train Epoch: 5 [51200/60000]	Loss: 1.790953
# Train Epoch: 5 [57600/60000]	Loss: 1.679120
# GA initialized with seed=32, d=61706, q=256, device=cpu
#
# Test set: Average loss: 0.0052, Accuracy: 2462/10000 (25%)
#
# q= 512
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=512, device=cpu
#
# Test set: Average loss: 0.0026, Accuracy: 4564/10000 (46%)
#
# Train Epoch: 2 [0/60000]	Loss: 9.334307
# Train Epoch: 2 [6400/60000]	Loss: 0.576538
# Train Epoch: 2 [12800/60000]	Loss: 0.665572
# Train Epoch: 2 [19200/60000]	Loss: 0.238824
# Train Epoch: 2 [25600/60000]	Loss: 0.481096
# Train Epoch: 2 [32000/60000]	Loss: 0.280608
# Train Epoch: 2 [38400/60000]	Loss: 0.441609
# Train Epoch: 2 [44800/60000]	Loss: 0.571350
# Train Epoch: 2 [51200/60000]	Loss: 0.290800
# Train Epoch: 2 [57600/60000]	Loss: 0.302167
# GA initialized with seed=90, d=61706, q=512, device=cpu
#
# Test set: Average loss: 0.0037, Accuracy: 3775/10000 (38%)
#
# Train Epoch: 3 [0/60000]	Loss: 11.552952
# Train Epoch: 3 [6400/60000]	Loss: 2.269374
# Train Epoch: 3 [12800/60000]	Loss: 1.173313
# Train Epoch: 3 [19200/60000]	Loss: 0.808590
# Train Epoch: 3 [25600/60000]	Loss: 1.020542
# Train Epoch: 3 [32000/60000]	Loss: 0.753694
# Train Epoch: 3 [38400/60000]	Loss: 0.838543
# Train Epoch: 3 [44800/60000]	Loss: 0.807653
# Train Epoch: 3 [51200/60000]	Loss: 0.462304
# Train Epoch: 3 [57600/60000]	Loss: 0.606510
# GA initialized with seed=20, d=61706, q=512, device=cpu
#
# Test set: Average loss: 0.0043, Accuracy: 3904/10000 (39%)
#
# Train Epoch: 4 [0/60000]	Loss: 11.428889
# Train Epoch: 4 [6400/60000]	Loss: 1.838737
# Train Epoch: 4 [12800/60000]	Loss: 1.521505
# Train Epoch: 4 [19200/60000]	Loss: 0.725457
# Train Epoch: 4 [25600/60000]	Loss: 0.993623
# Train Epoch: 4 [32000/60000]	Loss: 0.494722
# Train Epoch: 4 [38400/60000]	Loss: 0.533403
# Train Epoch: 4 [44800/60000]	Loss: 0.313340
# Train Epoch: 4 [51200/60000]	Loss: 0.748898
# Train Epoch: 4 [57600/60000]	Loss: 0.427373
# GA initialized with seed=22, d=61706, q=512, device=cpu
#
# Test set: Average loss: 0.0075, Accuracy: 3007/10000 (30%)
#
# Train Epoch: 5 [0/60000]	Loss: 14.198989
# Train Epoch: 5 [6400/60000]	Loss: 2.916883
# Train Epoch: 5 [12800/60000]	Loss: 2.730938
# Train Epoch: 5 [19200/60000]	Loss: 3.023444
# Train Epoch: 5 [25600/60000]	Loss: 2.641210
# Train Epoch: 5 [32000/60000]	Loss: 2.155278
# Train Epoch: 5 [38400/60000]	Loss: 2.268996
# Train Epoch: 5 [44800/60000]	Loss: 2.407700
# Train Epoch: 5 [51200/60000]	Loss: 2.514741
# Train Epoch: 5 [57600/60000]	Loss: 2.006750
# GA initialized with seed=32, d=61706, q=512, device=cpu
#
# Test set: Average loss: 0.0054, Accuracy: 3235/10000 (32%)
#
# q= 1024
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=1024, device=cpu
#
# Test set: Average loss: 0.0046, Accuracy: 2179/10000 (22%)
#
# Train Epoch: 2 [0/60000]	Loss: 8.728443
# Train Epoch: 2 [6400/60000]	Loss: 2.580897
# Train Epoch: 2 [12800/60000]	Loss: 1.604951
# Train Epoch: 2 [19200/60000]	Loss: 1.187120
# Train Epoch: 2 [25600/60000]	Loss: 1.021064
# Train Epoch: 2 [32000/60000]	Loss: 0.951397
# Train Epoch: 2 [38400/60000]	Loss: 0.682824
# Train Epoch: 2 [44800/60000]	Loss: 0.568163
# Train Epoch: 2 [51200/60000]	Loss: 0.544682
# Train Epoch: 2 [57600/60000]	Loss: 0.773290
# GA initialized with seed=90, d=61706, q=1024, device=cpu
#
# Test set: Average loss: 0.0101, Accuracy: 1403/10000 (14%)
#
# Train Epoch: 3 [0/60000]	Loss: 12.355100
# Train Epoch: 3 [6400/60000]	Loss: 3.112738
# Train Epoch: 3 [12800/60000]	Loss: 2.087868
# Train Epoch: 3 [19200/60000]	Loss: 2.642791
# Train Epoch: 3 [25600/60000]	Loss: 2.040893
# Train Epoch: 3 [32000/60000]	Loss: 2.421727
# Train Epoch: 3 [38400/60000]	Loss: 1.830470
# Train Epoch: 3 [44800/60000]	Loss: 2.362934
# Train Epoch: 3 [51200/60000]	Loss: 1.855076
# Train Epoch: 3 [57600/60000]	Loss: 1.956109
# GA initialized with seed=20, d=61706, q=1024, device=cpu
#
# Test set: Average loss: 0.0047, Accuracy: 2744/10000 (27%)
#
# Train Epoch: 4 [0/60000]	Loss: 9.812067
# Train Epoch: 4 [6400/60000]	Loss: 1.341094
# Train Epoch: 4 [12800/60000]	Loss: 1.808842
# Train Epoch: 4 [19200/60000]	Loss: 1.637592
# Train Epoch: 4 [25600/60000]	Loss: 1.617593
# Train Epoch: 4 [32000/60000]	Loss: 1.344349
# Train Epoch: 4 [38400/60000]	Loss: 1.227670
# Train Epoch: 4 [44800/60000]	Loss: 1.920663
# Train Epoch: 4 [51200/60000]	Loss: 0.901627
# Train Epoch: 4 [57600/60000]	Loss: 0.900419
# GA initialized with seed=22, d=61706, q=1024, device=cpu
#
# Test set: Average loss: 0.0081, Accuracy: 1933/10000 (19%)
#
# Train Epoch: 5 [0/60000]	Loss: 23.116329
# Train Epoch: 5 [6400/60000]	Loss: 2.171781
# Train Epoch: 5 [12800/60000]	Loss: 1.942223
# Train Epoch: 5 [19200/60000]	Loss: 1.831202
# Train Epoch: 5 [25600/60000]	Loss: 2.016461
# Train Epoch: 5 [32000/60000]	Loss: 1.848724
# Train Epoch: 5 [38400/60000]	Loss: 1.759587
# Train Epoch: 5 [44800/60000]	Loss: 1.722730
# Train Epoch: 5 [51200/60000]	Loss: 1.915996
# Train Epoch: 5 [57600/60000]	Loss: 1.625786
# GA initialized with seed=32, d=61706, q=1024, device=cpu
#
# Test set: Average loss: 0.0064, Accuracy: 2209/10000 (22%)
#
# q= 2048
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=2048, device=cpu
#
# Test set: Average loss: 0.0016, Accuracy: 5775/10000 (58%)
#
# Train Epoch: 2 [0/60000]	Loss: 7.754706
# Train Epoch: 2 [6400/60000]	Loss: 0.729322
# Train Epoch: 2 [12800/60000]	Loss: 1.522188
# Train Epoch: 2 [19200/60000]	Loss: 0.446551
# Train Epoch: 2 [25600/60000]	Loss: 0.393198
# Train Epoch: 2 [32000/60000]	Loss: 0.196847
# Train Epoch: 2 [38400/60000]	Loss: 0.280339
# Train Epoch: 2 [44800/60000]	Loss: 0.291814
# Train Epoch: 2 [51200/60000]	Loss: 0.664631
# Train Epoch: 2 [57600/60000]	Loss: 0.269438
# GA initialized with seed=90, d=61706, q=2048, device=cpu
#
# Test set: Average loss: 0.0046, Accuracy: 3735/10000 (37%)
#
# Train Epoch: 3 [0/60000]	Loss: 14.477675
# Train Epoch: 3 [6400/60000]	Loss: 2.603195
# Train Epoch: 3 [12800/60000]	Loss: 1.683636
# Train Epoch: 3 [19200/60000]	Loss: 1.471078
# Train Epoch: 3 [25600/60000]	Loss: 1.035471
# Train Epoch: 3 [32000/60000]	Loss: 0.984391
# Train Epoch: 3 [38400/60000]	Loss: 0.667762
# Train Epoch: 3 [44800/60000]	Loss: 1.038651
# Train Epoch: 3 [51200/60000]	Loss: 0.549373
# Train Epoch: 3 [57600/60000]	Loss: 0.892721
# GA initialized with seed=20, d=61706, q=2048, device=cpu
#
# Test set: Average loss: 0.0082, Accuracy: 2487/10000 (25%)
#
# Train Epoch: 4 [0/60000]	Loss: 12.361483
# Train Epoch: 4 [6400/60000]	Loss: 2.309619
# Train Epoch: 4 [12800/60000]	Loss: 2.737886
# Train Epoch: 4 [19200/60000]	Loss: 2.623778
# Train Epoch: 4 [25600/60000]	Loss: 3.092445
# Train Epoch: 4 [32000/60000]	Loss: 3.167365
# Train Epoch: 4 [38400/60000]	Loss: 2.067683
# Train Epoch: 4 [44800/60000]	Loss: 2.110602
# Train Epoch: 4 [51200/60000]	Loss: 2.476024
# Train Epoch: 4 [57600/60000]	Loss: 2.144288
# GA initialized with seed=22, d=61706, q=2048, device=cpu
#
# Test set: Average loss: 0.0109, Accuracy: 1294/10000 (13%)
#
# Train Epoch: 5 [0/60000]	Loss: 25.123163
# Train Epoch: 5 [6400/60000]	Loss: 2.526916
# Train Epoch: 5 [12800/60000]	Loss: 2.329075
# Train Epoch: 5 [19200/60000]	Loss: 2.384736
# Train Epoch: 5 [25600/60000]	Loss: 2.610570
# Train Epoch: 5 [32000/60000]	Loss: 2.203071
# Train Epoch: 5 [38400/60000]	Loss: 2.897547
# Train Epoch: 5 [44800/60000]	Loss: 1.987271
# Train Epoch: 5 [51200/60000]	Loss: 2.563606
# Train Epoch: 5 [57600/60000]	Loss: 2.677154
# GA initialized with seed=32, d=61706, q=2048, device=cpu
#
# Test set: Average loss: 0.0085, Accuracy: 1319/10000 (13%)
#
# q= 4096
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=4096, device=cpu
#
# Test set: Average loss: 0.0014, Accuracy: 6106/10000 (61%)
#
# Train Epoch: 2 [0/60000]	Loss: 7.445337
# Train Epoch: 2 [6400/60000]	Loss: 0.691737
# Train Epoch: 2 [12800/60000]	Loss: 0.601871
# Train Epoch: 2 [19200/60000]	Loss: 0.781014
# Train Epoch: 2 [25600/60000]	Loss: 0.524878
# Train Epoch: 2 [32000/60000]	Loss: 0.492372
# Train Epoch: 2 [38400/60000]	Loss: 0.553954
# Train Epoch: 2 [44800/60000]	Loss: 0.322662
# Train Epoch: 2 [51200/60000]	Loss: 0.209402
# Train Epoch: 2 [57600/60000]	Loss: 0.392021
# GA initialized with seed=90, d=61706, q=4096, device=cpu
#
# Test set: Average loss: 0.0020, Accuracy: 5617/10000 (56%)
#
# Train Epoch: 3 [0/60000]	Loss: 10.148204
# Train Epoch: 3 [6400/60000]	Loss: 1.215477
# Train Epoch: 3 [12800/60000]	Loss: 1.279289
# Train Epoch: 3 [19200/60000]	Loss: 1.056774
# Train Epoch: 3 [25600/60000]	Loss: 0.345115
# Train Epoch: 3 [32000/60000]	Loss: 0.712348
# Train Epoch: 3 [38400/60000]	Loss: 0.573916
# Train Epoch: 3 [44800/60000]	Loss: 0.456807
# Train Epoch: 3 [51200/60000]	Loss: 0.502759
# Train Epoch: 3 [57600/60000]	Loss: 0.307572
# GA initialized with seed=20, d=61706, q=4096, device=cpu
#
# Test set: Average loss: 0.0026, Accuracy: 4804/10000 (48%)
#
# Train Epoch: 4 [0/60000]	Loss: 10.272343
# Train Epoch: 4 [6400/60000]	Loss: 1.206336
# Train Epoch: 4 [12800/60000]	Loss: 0.581928
# Train Epoch: 4 [19200/60000]	Loss: 0.976462
# Train Epoch: 4 [25600/60000]	Loss: 0.379068
# Train Epoch: 4 [32000/60000]	Loss: 0.840299
# Train Epoch: 4 [38400/60000]	Loss: 0.515199
# Train Epoch: 4 [44800/60000]	Loss: 0.367678
# Train Epoch: 4 [51200/60000]	Loss: 0.513621
# Train Epoch: 4 [57600/60000]	Loss: 0.291013
# GA initialized with seed=22, d=61706, q=4096, device=cpu
#
# Test set: Average loss: 0.0026, Accuracy: 5515/10000 (55%)
#
# Train Epoch: 5 [0/60000]	Loss: 6.893469
# Train Epoch: 5 [6400/60000]	Loss: 1.189261
# Train Epoch: 5 [12800/60000]	Loss: 1.136363
# Train Epoch: 5 [19200/60000]	Loss: 0.449592
# Train Epoch: 5 [25600/60000]	Loss: 1.279677
# Train Epoch: 5 [32000/60000]	Loss: 0.657758
# Train Epoch: 5 [38400/60000]	Loss: 0.748087
# Train Epoch: 5 [44800/60000]	Loss: 0.538586
# Train Epoch: 5 [51200/60000]	Loss: 0.751279
# Train Epoch: 5 [57600/60000]	Loss: 0.604042
# GA initialized with seed=32, d=61706, q=4096, device=cpu
#
# Test set: Average loss: 0.0040, Accuracy: 4240/10000 (42%)
#
# q= 8192
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=8192, device=cpu
#
# Test set: Average loss: 0.0018, Accuracy: 5869/10000 (59%)
#
# Train Epoch: 2 [0/60000]	Loss: 7.265549
# Train Epoch: 2 [6400/60000]	Loss: 0.802486
# Train Epoch: 2 [12800/60000]	Loss: 0.734678
# Train Epoch: 2 [19200/60000]	Loss: 0.703550
# Train Epoch: 2 [25600/60000]	Loss: 0.511043
# Train Epoch: 2 [32000/60000]	Loss: 0.197410
# Train Epoch: 2 [38400/60000]	Loss: 0.359465
# Train Epoch: 2 [44800/60000]	Loss: 0.195081
# Train Epoch: 2 [51200/60000]	Loss: 0.190982
# Train Epoch: 2 [57600/60000]	Loss: 0.550760
# GA initialized with seed=90, d=61706, q=8192, device=cpu
#
# Test set: Average loss: 0.0023, Accuracy: 5287/10000 (53%)
#
# Train Epoch: 3 [0/60000]	Loss: 10.952689
# Train Epoch: 3 [6400/60000]	Loss: 1.259277
# Train Epoch: 3 [12800/60000]	Loss: 0.765856
# Train Epoch: 3 [19200/60000]	Loss: 0.716257
# Train Epoch: 3 [25600/60000]	Loss: 0.706896
# Train Epoch: 3 [32000/60000]	Loss: 0.369387
# Train Epoch: 3 [38400/60000]	Loss: 0.414336
# Train Epoch: 3 [44800/60000]	Loss: 0.353344
# Train Epoch: 3 [51200/60000]	Loss: 0.445360
# Train Epoch: 3 [57600/60000]	Loss: 0.294031
# GA initialized with seed=20, d=61706, q=8192, device=cpu
#
# Test set: Average loss: 0.0025, Accuracy: 4821/10000 (48%)
#
# Train Epoch: 4 [0/60000]	Loss: 9.392502
# Train Epoch: 4 [6400/60000]	Loss: 1.434715
# Train Epoch: 4 [12800/60000]	Loss: 0.975049
# Train Epoch: 4 [19200/60000]	Loss: 0.516581
# Train Epoch: 4 [25600/60000]	Loss: 0.600797
# Train Epoch: 4 [32000/60000]	Loss: 0.911416
# Train Epoch: 4 [38400/60000]	Loss: 0.416699
# Train Epoch: 4 [44800/60000]	Loss: 0.607779
# Train Epoch: 4 [51200/60000]	Loss: 0.525766
# Train Epoch: 4 [57600/60000]	Loss: 0.543775
# GA initialized with seed=22, d=61706, q=8192, device=cpu
#
# Test set: Average loss: 0.0035, Accuracy: 4333/10000 (43%)
#
# Train Epoch: 5 [0/60000]	Loss: 10.365830
# Train Epoch: 5 [6400/60000]	Loss: 0.972737
# Train Epoch: 5 [12800/60000]	Loss: 0.991388
# Train Epoch: 5 [19200/60000]	Loss: 0.899792
# Train Epoch: 5 [25600/60000]	Loss: 0.634821
# Train Epoch: 5 [32000/60000]	Loss: 0.654645
# Train Epoch: 5 [38400/60000]	Loss: 0.466297
# Train Epoch: 5 [44800/60000]	Loss: 0.633482
# Train Epoch: 5 [51200/60000]	Loss: 0.406481
# Train Epoch: 5 [57600/60000]	Loss: 0.618940
# GA initialized with seed=32, d=61706, q=8192, device=cpu
#
# Test set: Average loss: 0.0027, Accuracy: 4867/10000 (49%)
#
# q= 16384
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=16384, device=cpu
#
# Test set: Average loss: 0.0018, Accuracy: 5480/10000 (55%)
#
# Train Epoch: 2 [0/60000]	Loss: 8.353199
# Train Epoch: 2 [6400/60000]	Loss: 0.821700
# Train Epoch: 2 [12800/60000]	Loss: 0.500759
# Train Epoch: 2 [19200/60000]	Loss: 0.534815
# Train Epoch: 2 [25600/60000]	Loss: 0.902987
# Train Epoch: 2 [32000/60000]	Loss: 0.252836
# Train Epoch: 2 [38400/60000]	Loss: 0.476098
# Train Epoch: 2 [44800/60000]	Loss: 0.179034
# Train Epoch: 2 [51200/60000]	Loss: 0.296261
# Train Epoch: 2 [57600/60000]	Loss: 0.215341
# GA initialized with seed=90, d=61706, q=16384, device=cpu
#
# Test set: Average loss: 0.0047, Accuracy: 3765/10000 (38%)
#
# Train Epoch: 3 [0/60000]	Loss: 12.348250
# Train Epoch: 3 [6400/60000]	Loss: 2.557046
# Train Epoch: 3 [12800/60000]	Loss: 1.285867
# Train Epoch: 3 [19200/60000]	Loss: 1.251328
# Train Epoch: 3 [25600/60000]	Loss: 0.720387
# Train Epoch: 3 [32000/60000]	Loss: 0.841757
# Train Epoch: 3 [38400/60000]	Loss: 0.554127
# Train Epoch: 3 [44800/60000]	Loss: 0.317628
# Train Epoch: 3 [51200/60000]	Loss: 0.695465
# Train Epoch: 3 [57600/60000]	Loss: 0.756880
# GA initialized with seed=20, d=61706, q=16384, device=cpu
#
# Test set: Average loss: 0.0039, Accuracy: 4811/10000 (48%)
#
# Train Epoch: 4 [0/60000]	Loss: 11.699114
# Train Epoch: 4 [6400/60000]	Loss: 1.640570
# Train Epoch: 4 [12800/60000]	Loss: 1.439370
# Train Epoch: 4 [19200/60000]	Loss: 0.734125
# Train Epoch: 4 [25600/60000]	Loss: 0.326989
# Train Epoch: 4 [32000/60000]	Loss: 0.986328
# Train Epoch: 4 [38400/60000]	Loss: 0.450969
# Train Epoch: 4 [44800/60000]	Loss: 0.360975
# Train Epoch: 4 [51200/60000]	Loss: 0.689189
# Train Epoch: 4 [57600/60000]	Loss: 0.560060
# GA initialized with seed=22, d=61706, q=16384, device=cpu
#
# Test set: Average loss: 0.0174, Accuracy: 1233/10000 (12%)
#
# Train Epoch: 5 [0/60000]	Loss: 29.364037
# Train Epoch: 5 [6400/60000]	Loss: 3.558003
# Train Epoch: 5 [12800/60000]	Loss: 2.839493
# Train Epoch: 5 [19200/60000]	Loss: 2.880967
# Train Epoch: 5 [25600/60000]	Loss: 2.999614
# Train Epoch: 5 [32000/60000]	Loss: 2.561204
# Train Epoch: 5 [38400/60000]	Loss: 2.927762
# Train Epoch: 5 [44800/60000]	Loss: 2.431334
# Train Epoch: 5 [51200/60000]	Loss: 2.688870
# Train Epoch: 5 [57600/60000]	Loss: 2.389325
# GA initialized with seed=32, d=61706, q=16384, device=cpu
#
# Test set: Average loss: 0.0106, Accuracy: 1316/10000 (13%)
#
# q= 32768
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=32768, device=cpu
#
# Test set: Average loss: 0.0017, Accuracy: 6018/10000 (60%)
#
# Train Epoch: 2 [0/60000]	Loss: 10.482222
# Train Epoch: 2 [6400/60000]	Loss: 0.492021
# Train Epoch: 2 [12800/60000]	Loss: 0.422214
# Train Epoch: 2 [19200/60000]	Loss: 0.307634
# Train Epoch: 2 [25600/60000]	Loss: 0.274159
# Train Epoch: 2 [32000/60000]	Loss: 0.378671
# Train Epoch: 2 [38400/60000]	Loss: 0.409721
# Train Epoch: 2 [44800/60000]	Loss: 0.245353
# Train Epoch: 2 [51200/60000]	Loss: 0.525121
# Train Epoch: 2 [57600/60000]	Loss: 0.308225
# GA initialized with seed=90, d=61706, q=32768, device=cpu
#
# Test set: Average loss: 0.0015, Accuracy: 6717/10000 (67%)
#
# Train Epoch: 3 [0/60000]	Loss: 6.778452
# Train Epoch: 3 [6400/60000]	Loss: 1.241021
# Train Epoch: 3 [12800/60000]	Loss: 0.676295
# Train Epoch: 3 [19200/60000]	Loss: 0.614545
# Train Epoch: 3 [25600/60000]	Loss: 0.648674
# Train Epoch: 3 [32000/60000]	Loss: 0.416055
# Train Epoch: 3 [38400/60000]	Loss: 0.802781
# Train Epoch: 3 [44800/60000]	Loss: 0.177343
# Train Epoch: 3 [51200/60000]	Loss: 0.341501
# Train Epoch: 3 [57600/60000]	Loss: 0.655551
# GA initialized with seed=20, d=61706, q=32768, device=cpu
#
# Test set: Average loss: 0.0019, Accuracy: 5508/10000 (55%)
#
# Train Epoch: 4 [0/60000]	Loss: 8.396315
# Train Epoch: 4 [6400/60000]	Loss: 1.410571
# Train Epoch: 4 [12800/60000]	Loss: 0.782194
# Train Epoch: 4 [19200/60000]	Loss: 1.312169
# Train Epoch: 4 [25600/60000]	Loss: 0.978186
# Train Epoch: 4 [32000/60000]	Loss: 0.431295
# Train Epoch: 4 [38400/60000]	Loss: 0.468383
# Train Epoch: 4 [44800/60000]	Loss: 0.711425
# Train Epoch: 4 [51200/60000]	Loss: 0.496317
# Train Epoch: 4 [57600/60000]	Loss: 0.148872
# GA initialized with seed=22, d=61706, q=32768, device=cpu
#
# Test set: Average loss: 0.0025, Accuracy: 5097/10000 (51%)
#
# Train Epoch: 5 [0/60000]	Loss: 7.228264
# Train Epoch: 5 [6400/60000]	Loss: 0.646077
# Train Epoch: 5 [12800/60000]	Loss: 1.334549
# Train Epoch: 5 [19200/60000]	Loss: 1.109072
# Train Epoch: 5 [25600/60000]	Loss: 0.764281
# Train Epoch: 5 [32000/60000]	Loss: 1.128489
# Train Epoch: 5 [38400/60000]	Loss: 0.836498
# Train Epoch: 5 [44800/60000]	Loss: 0.634053
# Train Epoch: 5 [51200/60000]	Loss: 0.592543
# Train Epoch: 5 [57600/60000]	Loss: 0.487651
# GA initialized with seed=32, d=61706, q=32768, device=cpu
#
# Test set: Average loss: 0.0049, Accuracy: 3294/10000 (33%)
#
# q= 65536
# Train Epoch: 1 [0/60000]	Loss: 2.306540
# Train Epoch: 1 [6400/60000]	Loss: 0.202203
# Train Epoch: 1 [12800/60000]	Loss: 0.471449
# Train Epoch: 1 [19200/60000]	Loss: 0.070377
# Train Epoch: 1 [25600/60000]	Loss: 0.287195
# Train Epoch: 1 [32000/60000]	Loss: 0.180319
# Train Epoch: 1 [38400/60000]	Loss: 0.106414
# Train Epoch: 1 [44800/60000]	Loss: 0.342011
# Train Epoch: 1 [51200/60000]	Loss: 0.484629
# Train Epoch: 1 [57600/60000]	Loss: 0.438163
# GA initialized with seed=45, d=61706, q=65536, device=cpu
#
# Test set: Average loss: 0.0026, Accuracy: 4042/10000 (40%)
#
# Train Epoch: 2 [0/60000]	Loss: 9.077737
# Train Epoch: 2 [6400/60000]	Loss: 1.458023
# Train Epoch: 2 [12800/60000]	Loss: 0.901031
# Train Epoch: 2 [19200/60000]	Loss: 1.411445
# Train Epoch: 2 [25600/60000]	Loss: 0.594102
# Train Epoch: 2 [32000/60000]	Loss: 0.385963
# Train Epoch: 2 [38400/60000]	Loss: 0.412721
# Train Epoch: 2 [44800/60000]	Loss: 0.389462
# Train Epoch: 2 [51200/60000]	Loss: 0.535294
# Train Epoch: 2 [57600/60000]	Loss: 0.561475
# GA initialized with seed=90, d=61706, q=65536, device=cpu
#
# Test set: Average loss: 0.0020, Accuracy: 5945/10000 (59%)
#
# Train Epoch: 3 [0/60000]	Loss: 6.050508
# Train Epoch: 3 [6400/60000]	Loss: 0.885545
# Train Epoch: 3 [12800/60000]	Loss: 0.923165
# Train Epoch: 3 [19200/60000]	Loss: 0.594695
# Train Epoch: 3 [25600/60000]	Loss: 0.596405
# Train Epoch: 3 [32000/60000]	Loss: 0.295725
# Train Epoch: 3 [38400/60000]	Loss: 0.489253
# Train Epoch: 3 [44800/60000]	Loss: 0.657276
# Train Epoch: 3 [51200/60000]	Loss: 0.581688
# Train Epoch: 3 [57600/60000]	Loss: 0.634523
# GA initialized with seed=20, d=61706, q=65536, device=cpu
#
# Test set: Average loss: 0.0025, Accuracy: 5739/10000 (57%)
#
# Train Epoch: 4 [0/60000]	Loss: 8.104152
# Train Epoch: 4 [6400/60000]	Loss: 2.044216
# Train Epoch: 4 [12800/60000]	Loss: 1.040225
# Train Epoch: 4 [19200/60000]	Loss: 1.147392
# Train Epoch: 4 [25600/60000]	Loss: 0.412813
# Train Epoch: 4 [32000/60000]	Loss: 0.576452
# Train Epoch: 4 [38400/60000]	Loss: 0.760061
# Train Epoch: 4 [44800/60000]	Loss: 0.784127
# Train Epoch: 4 [51200/60000]	Loss: 0.634139
# Train Epoch: 4 [57600/60000]	Loss: 0.734872
# GA initialized with seed=22, d=61706, q=65536, device=cpu
#
# Test set: Average loss: 0.0022, Accuracy: 5573/10000 (56%)
#
# Train Epoch: 5 [0/60000]	Loss: 8.389280
# Train Epoch: 5 [6400/60000]	Loss: 0.983260
# Train Epoch: 5 [12800/60000]	Loss: 1.515204
# Train Epoch: 5 [19200/60000]	Loss: 0.758461
# Train Epoch: 5 [25600/60000]	Loss: 0.731410
# Train Epoch: 5 [32000/60000]	Loss: 0.629511
# Train Epoch: 5 [38400/60000]	Loss: 0.667904
# Train Epoch: 5 [44800/60000]	Loss: 0.383849
# Train Epoch: 5 [51200/60000]	Loss: 0.598282
# Train Epoch: 5 [57600/60000]	Loss: 0.527826
# GA initialized with seed=32, d=61706, q=65536, device=cpu
#
# Test set: Average loss: 0.0044, Accuracy: 3458/10000 (35%)

# %%
import pandas as pd

df = pd.DataFrame(approximation_errors)
df = df.reset_index().melt(id_vars='index', var_name='Outer Key', value_name='Value')
df.columns = ['Round', 'Q', 'Tensor']
df['L2 Norm Error'] = df['Tensor'].apply(lambda x: x.item())
df
# Out:
#     Round      Q             Tensor  L2 Norm Error
# 0       1      1   tensor(216.9930)     216.992966
# 1       2      1   tensor(394.6845)     394.684540
# 2       3      1   tensor(772.8343)     772.834290
# 3       4      1  tensor(1125.3345)    1125.334473
# 4       5      1  tensor(1300.7971)    1300.797119
# ..    ...    ...                ...            ...
# 80      1  65536   tensor(112.9188)     112.918793
# 81      2  65536   tensor(146.2097)     146.209717
# 82      3  65536   tensor(141.5714)     141.571426
# 83      4  65536   tensor(151.6199)     151.619904
# 84      5  65536   tensor(143.9507)     143.950653
#
# [85 rows x 4 columns]

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Q', y='L2 Norm Error', hue='Round', marker='o')

# Add labels and title
plt.title('Plot of L2 Norm Error vs q by Round')
plt.xlabel('q')
plt.ylabel('L2 Norm (Gw - Δ )')
plt.show()

# %%
filtered_df = df[df['Round'] == 1]

# Plot the filtered data
plt.figure(figsize=(10, 6))
sns.lineplot(data=filtered_df, x='Q', y='L2 Norm Error', marker='o')

# Add labels and title
plt.title('Plot of L2 Norm Error vs Q for Round 1')
plt.xlabel('Q')
plt.ylabel('L2 Norm (Gw - Δ )')
plt.show()

# %%
filtered_df = df[df['Round'] == 5]

# Plot the filtered data
plt.figure(figsize=(10, 6))
sns.lineplot(data=filtered_df, x='Q', y='L2 Norm Error', marker='o')

# Add labels and title
plt.title('Plot of L2 Norm Error vs Q for Round 5')
plt.xlabel('Q')
plt.ylabel('L2 Norm (Gw - Δ )')
plt.show()

# %%
filtered_df = df[df['Round'] == 3]

# Plot the filtered data
plt.figure(figsize=(10, 6))
sns.lineplot(data=filtered_df, x='Q', y='L2 Norm Error', marker='o')

# Add labels and title
plt.title('Plot of L2 Norm Error vs Q for Round 3')
plt.xlabel('Q')
plt.ylabel('L2 Norm (Gw - Δ )')
plt.show()
